# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Pandas/users.csv", sep=";")

# %%
df_new = df[df["sex"] == "F"]
df_new = df_new[["username", "mail"]]

# %%
print(df_new)
# Out:
#         username                        mail
# 0    lambertemma            vsmith@yahoo.com
# 1          greid     graceholloway@yahoo.com
# 3      kristin75           stacy77@yahoo.com
# 6           ecox      kimrosario@hotmail.com
# 8       markhall  edwardswilliam@hotmail.com
# ..           ...                         ...
# 188   moorekelly      lauragardner@yahoo.com
# 190  vazquezjohn     scottnicholas@gmail.com
# 194     justin25           ewalker@yahoo.com
# 197     robert89          lsimmons@gmail.com
# 198       todd08    hilladrienne@hotmail.com
#
# [105 rows x 2 columns]

# %%
df_new.to_csv('output.csv', index=False, encoding='utf-8', sep=";")

# %%
df = pd.read_csv("Pandas/users.csv", sep=";", nrows=50)

# %%
df_new = df[df["sex"] == "M"]

# %%
print(len(df_new))
# Out:
# 27

# %%
blood_A = 0
count = 0
for chunk in pd.read_csv("Pandas/users.csv", sep=";", chunksize=30):
    count += 1
    if count == 5:
        blood_A = len(chunk[chunk["blood_group"] == "A+"])

# %%
print(blood_A)
# Out:
# 4

# %%
df
# Out:
#                                 job          company          ssn
# 0                   Records manager    Duncan-Garcia  241-62-8803  \
# 1               Mental health nurse         Rose-Lee  899-12-4937
# 2    Furniture conservator/restorer   Potts and Sons  261-41-9484
# 3                  Ambulance person       Rivera Inc  201-43-6181
# 4        Contracting civil engineer   Hatfield Group  878-83-6667
# ..                              ...              ...          ...
# 195            Journalist, magazine   Sanchez-Gaines  875-62-2622
# 196    Fast food restaurant manager  Clarke and Sons  765-06-4388
# 197              Surveyor, quantity     Clarke-Sloan  145-26-8248
# 198       Psychologist, counselling       Flores LLC  200-23-4183
# 199                    Metallurgist   Ochoa and Sons  368-59-9211
#
#                                              residence
# 0             309 Danielle Cliffs\nNorth Amy, NC 69960  \
# 1                     Unit 5929 Box 0845\nDPO AE 45149
# ...
