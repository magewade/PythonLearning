# %%
import pandas as pd
import lxml

# %%
xml_data = open("users.xml").read()
df = pd.read_xml(xml_data, parser='etree')
df
# Out:
#                                               address      birthdate
# 0           29948 Mason Summit\nRoblesshire, VA 63080  -620352000000  \
# 1    65586 Beverly Camp Apt. 519\nToddshire, NY 32950   813456000000
# 2                    Unit 5719 Box 7188\nDPO AA 69227 -1544140800000
# 3          4201 Sydney Brooks\nPort Raymond, ND 10924 -1363219200000
# 4         97225 Matthew Branch\nNew Caitlyn, IN 59591 -1033603200000
# 5   75979 Garcia Groves Suite 468\nPort Amyberg, H...  -677548800000
# 6   460 Dominique Path Suite 615\nTravisburgh, SD ...  -612057600000
# 7   52009 Margaret Parks Suite 245\nLake Stephanie... -1306886400000
# 8            51829 Warner Place\nJarvisstad, CT 78217   151372800000
# 9          22460 Townsend Knolls\nAliceside, MD 90237   268358400000
# 10  93977 Parker Avenue Apt. 625\nEast Williammout...   113011200000
# 11         55234 Murray Forest\nKrystalland, AK 12525 -1521072000000
# 12  90186 Austin Plains Apt. 551\nSarashire, DE 18781  1403049600000
# ...

# %%
print(len(df[(df['sex'] == 'F') & (df['blood_group'] == "B+")]))
# Out:
#                0
# 0          axis0
# 1          axis1
# 2   block0_items
# 3  block0_values
# 4   block1_items
# 5  block1_values
# 6   block2_items
# 7  block2_values

# %%
df = pd.read_html("/Users/magewade/Desktop/Python/Pandas/23110000100100200001_Общий_прирост_постоянного_населения.html")
df2 = df[0]
df2
# Out:
#                         Unnamed: 0    Unnamed: 1
# 0                              NaN           NaN  \
# 1                              NaN           NaN
# 2                    все население  w2:p_mest:11
# 3             Российская Федерация           643
# 4    Центральный федеральный округ           030
# ..                             ...           ...
# 98             Магаданская область   44000000000
# 99             Сахалинская область   64000000000
# 100   Еврейская автономная область   99000000000
# 101     Чукотский автономный округ   77000000000
# 102     Крымский федеральный округ           039
#
#     23110000100100200001 Общий прирост постоянного населения
# 0                                            За период        \
# 1                                       январь 2022 г.
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...

# %%
df3 = df2[(df2.iloc[:, 0] == "Камчатский край") | (df2.iloc[:, 0].isna())]
df3 = df3.fillna(value=0)
df3.iloc[2, 2:] = df3.iloc[2, 2:].astype(int)
df3
# Out:
#          Unnamed: 0   Unnamed: 1
# 0                 0            0  \
# 1                 0            0
# 94  Камчатский край  30000000000
#
#    23110000100100200001 Общий прирост постоянного населения
# 0                                           За период        \
# 1                                      январь 2022 г.
# 94                                                  0
#
#    23110000100100200001 Общий прирост постоянного населения.1
# 0                                           За период          \
# 1                                             2014 г.
# 94                                              -2595
#
#    23110000100100200001 Общий прирост постоянного населения.2
# 0                                           За период          \
# 1                                             2015 г.
# 94                                              -1153
#
#    23110000100100200001 Общий прирост постоянного населения.3
# ...

# %%
result = df3.iloc[2, 2:].sum()
result
# Out:
# -7160

# %%
-7160 - 1037
# Out:
# -8197
